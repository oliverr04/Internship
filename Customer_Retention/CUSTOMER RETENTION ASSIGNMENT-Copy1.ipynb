# %% [markdown]
# # CUSTOMER RETENTION

# %% [markdown]
# PROBLEM STATEMENT:

# %% [markdown]
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
pd.pandas.set_option("display.max_columns",None)

# %%
df_cr=pd.read_excel(r"C:\Users\user\Documents\customer_retention_dataset_1.xlsx",sheet_name='datasheet')
print(df_cr)
# Out:
#     Gender of respondent   How old are you?   \
# 0                   Male         31-40 years
# 1                 Female         21-30 years
# 2                 Female         21-30 years
# 3                   Male         21-30 years
# 4                 Female         21-30 years
# ..                   ...                 ...
# 264               Female         21-30 years
# 265               Female         31-40 years
# 266               Female         41-50 yaers
# 267               Female  Less than 20 years
# 268               Female         41-50 yaers
#
#     Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# ..                                  ...
# 264                               Solan
# 265                           Ghaziabad
# 266                          Bangalore
# ...

# %%
df_cr1=pd.read_excel(r"C:\Users\user\Documents\customer_retention_dataset_1.xlsx",sheet_name='codedsheet')
print(df_cr1)
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df_cr.head(10)
# Out:
#   Gender of respondent   How old are you?   \
# 0                 Male         31-40 years
# 1               Female         21-30 years
# 2               Female         21-30 years
# 3                 Male         21-30 years
# 4               Female         21-30 years
# 5               Female         31-40 years
# 6                 Male         41-50 yaers
# 7                 Male         41-50 yaers
# 8               Female  Less than 20 years
# 9               Female         31-40 years
#
#   Which city do you shop online from?  \
# 0                               Delhi
# 1                               Delhi
# 2                       Greater Noida
# 3                             Karnal
# 4                          Bangalore
# 5                               Noida
# 6                               Delhi
# 7                               Delhi
# 8                               Solan
# 9                               Delhi
#
# ...

# %%
df_cr.tail(10)
# Out:
#     Gender of respondent   How old are you?   \
# 259               Female         31-40 years
# 260               Female         31-40 years
# 261               Female         21-30 years
# 262               Female         21-30 years
# 263                 Male         41-50 yaers
# 264               Female         21-30 years
# 265               Female         31-40 years
# 266               Female         41-50 yaers
# 267               Female  Less than 20 years
# 268               Female         41-50 yaers
#
#     Which city do you shop online from?  \
# 259                       Greater Noida
# 260                               Noida
# 261                       Greater Noida
# 262                          Bangalore
# 263                               Delhi
# 264                               Solan
# 265                           Ghaziabad
# 266                          Bangalore
# 267                               Solan
# 268                           Ghaziabad
#
# ...

# %%
df_cr.shape
# Out:
# (269, 71)

# %% [markdown]
# There are 269 rows and 71 Columns in this dataset.

# %%
# checking null values
df_cr.isnull()
# Out:
#      Gender of respondent  How old are you?   \
# 0                   False              False
# 1                   False              False
# 2                   False              False
# 3                   False              False
# 4                   False              False
# ..                    ...                ...
# 264                 False              False
# 265                 False              False
# 266                 False              False
# 267                 False              False
# 268                 False              False
#
#      Which city do you shop online from?  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 264                                False
# 265                                False
# ...

# %%
# sum of null values (if any)
df_cr.isnull().sum()
# Out:
# Gender of respondent                                                    0
# How old are you?                                                        0
# Which city do you shop online from?                                     0
# What is the Pin Code of where you shop online from?                     0
# Since How Long You are Shopping Online?                                 0
#                                                                        ..
# Longer delivery period.                                                 0
# Change in website/Application design.                                   0
# Frequent disruption when moving from one page to another.               0
# Website is as efficient as before.                                      0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# There are no null values present in the dataset.

# %%
# Visualizing the null values
plt.figure(figsize=[20,8])
sns.heatmap(df_cr.isnull())
plt.title("Null Values")
plt.show()

# %%
# checking unique values in each columns
df_cr.nunique()
# Out:
# Gender of respondent                                                     2
# How old are you?                                                         5
# Which city do you shop online from?                                     11
# What is the Pin Code of where you shop online from?                     39
# Since How Long You are Shopping Online?                                  5
#                                                                         ..
# Longer delivery period.                                                  6
# Change in website/Application design.                                    7
# Frequent disruption when moving from one page to another.                8
# Website is as efficient as before.                                       8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
# checking data types
df_cr.dtypes
# Out:
# Gender of respondent                                                    object
# How old are you?                                                        object
# Which city do you shop online from?                                     object
# What is the Pin Code of where you shop online from?                      int64
# Since How Long You are Shopping Online?                                 object
#                                                                          ...
# Longer delivery period.                                                 object
# Change in website/Application design.                                   object
# Frequent disruption when moving from one page to another.               object
# Website is as efficient as before.                                      object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# Most of the columns are of "object" data type.

# %%
df_cr.describe()
# Out:
#        What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df_cr.describe(include='all')
# Out:
#        Gender of respondent How old are you?   \
# count                   269               269
# unique                    2                 5
# top                  Female       31-40 years
# freq                    181                81
# mean                    NaN               NaN
# std                     NaN               NaN
# min                     NaN               NaN
# 25%                     NaN               NaN
# 50%                     NaN               NaN
# 75%                     NaN               NaN
# max                     NaN               NaN
#
#        Which city do you shop online from?  \
# count                                  269
# unique                                  11
# top                                  Delhi
# freq                                    58
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# ...

# %%
df_cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0   Gender of respondent                                                                                       269 non-null    object
#  1   How old are you?                                                                                           269 non-null    object
#  2   Which city do you shop online from?                                                                        269 non-null    object
#  3   What is the Pin Code of where you shop online from?                                                        269 non-null    int64
# ...

# %%
# columns
df_cr.columns
# Out:
# Index(['Gender of respondent', 'How old are you? ',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online?',
#        'How many times you have made an online purchase in the past 1 year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %%
# Value counts of each column...
for i in df_cr.columns:
        print(df_cr[i].value_counts())
        print('-------------------------------------------------------------')
# Out:
# Female    181
# Male       88
# Name: Gender of respondent, dtype: int64
# -------------------------------------------------------------
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: How old are you? , dtype: int64
# -------------------------------------------------------------
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: Which city do you shop online from?, dtype: int64
# -------------------------------------------------------------
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# ...

# %%
# Checking the data for missing values
missing_values=[m for m in df_cr.columns if df_cr[m].isnull().sum()>1]
missing_values
# Out:
# []

# %% [markdown]
# There are no missing values in the data

# %%
# Checking the number of numerical features
numerical=[num for num in df_cr.columns if df_cr[num].dtypes!="O"]
df_cr[numerical]
# Out:
#      What is the Pin Code of where you shop online from?
# 0                                               110009
# 1                                               110030
# 2                                               201308
# 3                                               132001
# 4                                               530068
# ..                                                 ...
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
# [269 rows x 1 columns]

# %%
print('Number of numerical columns', len(numerical))
# Out:
# Number of numerical columns 1

# %% [markdown]
# Only 1 column : "What is the Pin Code of where you shop online from?" is a numerical column.

# %%
# Checking the discrete features
discrete=[dis for dis in df_cr.columns if dis not in numerical]
df_cr[discrete]
# Out:
#     Gender of respondent   How old are you?   \
# 0                   Male         31-40 years
# 1                 Female         21-30 years
# 2                 Female         21-30 years
# 3                   Male         21-30 years
# 4                 Female         21-30 years
# ..                   ...                 ...
# 264               Female         21-30 years
# 265               Female         31-40 years
# 266               Female         41-50 yaers
# 267               Female  Less than 20 years
# 268               Female         41-50 yaers
#
#     Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# ..                                  ...
# 264                               Solan
# 265                           Ghaziabad
# 266                          Bangalore
# ...

# %%
print("Count of discrete columns:", len(discrete))
# Out:
# Count of discrete columns: 70

# %% [markdown]
# There are 70 discrete columns in the dataset.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# We will analyse the dataset using various data visualization methods.

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# We will now analyse each column of the dataset.

# %%
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

# %%
plt.figure(figsize=(5,5))
print(df_cr['Gender of respondent'].value_counts())
sns.countplot(df_cr['Gender of respondent'].sort_values())
# Out:
# Female    181
# Male       88
# Name: Gender of respondent, dtype: int64
# <AxesSubplot:xlabel='Gender of respondent', ylabel='count'>

# %% [markdown]
# It is observed that the number of female respondants (181) is more than twice the number of male respondants(88).

# %%
plt.figure(figsize=(10,6))
print(df_cr['How old are you? '].value_counts())
sns.countplot(df_cr['How old are you? '].sort_values())
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: How old are you? , dtype: int64
# <AxesSubplot:xlabel='How old are you? ', ylabel='count'>

# %% [markdown]
# More than 80 % of the respondants fall between the age of 21 and 50 years of age, only 20 respondants are below the age of 20. Also, 19 respondants are above the age of 50.

# %%
plt.figure(figsize=(13,7))
print(df_cr['Which city do you shop online from?'].value_counts())
sns.countplot(df_cr['Which city do you shop online from?'].sort_values())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: Which city do you shop online from?, dtype: int64
# <AxesSubplot:xlabel='Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# We see that most people shop online from Delhi & very few people are ordering from Bulandshahr. Metropolitan cities like Delhi, Noida and Bangalore show a large number of online shoppers.
# In decreasing order: Delhi, Greater Noida, Noida, Bangalore, Karnal, Solan, Ghaziabad,Gurgaon, Meerut, Moradabad, Bulandshahr.

# %%
plt.figure(figsize=(10,5))
print(df_cr['Since How Long You are Shopping Online?'].value_counts())
sns.countplot(df_cr['Since How Long You are Shopping Online?'].sort_values(),palette="Set1")
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Since How Long You are Shopping Online?, dtype: int64
# <AxesSubplot:xlabel='Since How Long You are Shopping Online?', ylabel='count'>

# %% [markdown]
# We can see that most of the online shoppers in our dataset have more than 4 years of online shopping experience.Very few of the shoppers have experience of 1-2 years.

# %%
plt.figure(figsize=(10,5))
print(df_cr['How many times you have made an online purchase in the past 1 year?'].value_counts())
sns.countplot(df_cr['How many times you have made an online purchase in the past 1 year?'].sort_values(),palette="Set2")
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: How many times you have made an online purchase in the past 1 year?, dtype: int64
# <AxesSubplot:xlabel='How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# Majority of people have shopped less than 10 times in the past 1 year(114). Whereas, 6 of our respondants have shopped more than 42 times this past year.

# %%
plt.figure(figsize=(10,5))
print(df_cr['How do you access the internet while shopping on-line?'].value_counts())
df_cr['How do you access the internet while shopping on-line?'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: How do you access the internet while shopping on-line?, dtype: int64
# <AxesSubplot:ylabel='How do you access the internet while shopping on-line?'>

# %% [markdown]
# Majority of our respondants use Mobile Internet or Mobile Data to shop online. After, Mobile Internet many use Wi-Fi for online shopping. Dial up is the least used to access the internet while shopping online.

# %%
plt.figure(figsize=(10,5))
print(df_cr['Which device do you use to access the online shopping?'].value_counts())
df_cr['Which device do you use to access the online shopping?'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: Which device do you use to access the online shopping?, dtype: int64
# <AxesSubplot:ylabel='Which device do you use to access the online shopping?'>

# %% [markdown]
# Smartphones and laptops are the most used electronic devices to shop online. Very few respondants shop online using tablets.

# %%
plt.figure(figsize=(8,6))
print(df_cr['What is the screen size of your mobile device?'].value_counts())
sns.countplot(df_cr['What is the screen size of your mobile device?'].sort_values(),palette="Set1")
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: What is the screen size of your mobile device?, dtype: int64
# <AxesSubplot:xlabel='What is the screen size of your mobile device?', ylabel='count'>

# %% [markdown]
# According to the data, most people have screen size apart from 4.7,5.5,5 inches. Next to that most people have 5.5 inches of screensize of the mobile.

# %%
plt.figure(figsize=(5,5))
print(df_cr['What is the operating system (OS) of your device?'].value_counts())
df_cr['What is the operating system (OS) of your device?'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: What is the operating system (OS) of your device?, dtype: int64
# <AxesSubplot:ylabel='What is the operating system (OS) of your device?'>

# %% [markdown]
# From the above chart, we conclude that the major operating system (OS) is Windows/Windows Mobile, followed by Android and lastly, IOS/Mac.

# %%
plt.figure(figsize=(5,5))
print(df_cr['What browser do you run on your device to access the website?'].value_counts())
df_cr['What browser do you run on your device to access the website?'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: What browser do you run on your device to access the website?, dtype: int64
# <AxesSubplot:ylabel='What browser do you run on your device to access the website?'>

# %% [markdown]
# Most of our respondants use Google Chrome to shop online as it is a default browser in most devices. Safari is next which is the default browser in IOS and Mac devices. Mozilla Firefox is the least used browser to access the website

# %%
plt.figure(figsize=(5,5))
print(df_cr['Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts())
df_cr['Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64
# <AxesSubplot:ylabel='Which channel did you follow to arrive at your favorite online store for the first time?'>

# %% [markdown]
# It is observed that search engines are the main channels used to arrive at our respondants favourite online stores for the first time, followed by Content Marketing and Display Advertisements.

# %%
plt.figure(figsize=(8,6))
print(df_cr['After first visit, how do you reach the online retail store?'].value_counts())
sns.countplot(df_cr['After first visit, how do you reach the online retail store?'].sort_values(),palette="Set1")
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: After first visit, how do you reach the online retail store?, dtype: int64
# <AxesSubplot:xlabel='After first visit, how do you reach the online retail store?', ylabel='count'>

# %% [markdown]
# After the first visit, Majority of our respondants reached the online retail store through search engines and via applications. Followed by direct URLs. Social Media and Emails were the least.

# %%
plt.figure(figsize=(8,6))
print(df_cr['How much time do you explore the e- retail store before making a purchase decision?'].value_counts())
sns.countplot(df_cr['How much time do you explore the e- retail store before making a purchase decision?'].sort_values(),palette="Set2")
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: How much time do you explore the e- retail store before making a purchase decision?, dtype: int64
# <AxesSubplot:xlabel='How much time do you explore the e- retail store before making a purchase decision?', ylabel='count'>

# %% [markdown]
# Majority of our respondants spent a good 15 minutes before making their purchase decision. 15 respondants spent less than 1 min to make a purchase decision.

# %%
plt.figure(figsize=(5,5))
print(df_cr['What is your preferred payment Option?'].value_counts())
df_cr['What is your preferred payment Option?'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: What is your preferred payment Option?, dtype: int64
# <AxesSubplot:ylabel='What is your preferred payment Option?'>

# %% [markdown]
# Debit/Credit cards are the preferred payment option by most of our respondants(148).COD is also a major preferred payment option. Very few of our respondants use E-Wallets such as Paytm, freecharge etc. for online payments.

# %%
plt.figure(figsize=(5,5))
print(df_cr['How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts())
sns.countplot(df_cr['How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].sort_values(),palette=None)
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64
# <AxesSubplot:xlabel='How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?', ylabel='count'>

# %% [markdown]
# Most of our respondants abandon the items in their shopping cart 'Sometimes' while shopping online. 48 of our respondants 'never' abandon items in their shopping cart.

# %%
plt.figure(figsize=(10,7))
print(df_cr['Why did you abandon the “Bag”, “Shopping Cart”?					'].value_counts())
sns.countplot(df_cr['Why did you abandon the “Bag”, “Shopping Cart”?					'].sort_values(),palette="Set1")
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t, dtype: int64
# <AxesSubplot:xlabel='Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t', ylabel='count'>

# %% [markdown]
# Most of our respondants, abandoned their "bag", "shopping cart" because they got a better alternative offer. Next, because the promo code wasn't applicable. Lastly, due to no preffered mode of payment.

# %%
plt.figure(figsize=(10,6))
print(df_cr['The content on the website must be easy to read and understand.'].value_counts())
sns.countplot(y=df_cr['The content on the website must be easy to read and understand.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: The content on the website must be easy to read and understand., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='The content on the website must be easy to read and understand.'>

# %% [markdown]
# Majority of the respondants found the content on the website easy to read and understand. A very small minority were indifferent towards this. Most agreed to the above statement.

# %%
plt.figure(figsize=(8,7))
print(df_cr['Information on similar product to the one highlighted  is important for product comparison.'].value_counts())
sns.countplot(df_cr['Information on similar product to the one highlighted  is important for product comparison.'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: Information on similar product to the one highlighted  is important for product comparison., dtype: int64
# <AxesSubplot:xlabel='Information on similar product to the one highlighted  is important for product comparison.', ylabel='count'>

# %% [markdown]
# As seen in the above chart, most of our respondants find that Information on similar product to the one highlighted  is important for product comparison. Very few disagree with the statement.

# %%
plt.figure(figsize=(8,9))
print(df_cr['Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
sns.countplot(df_cr['Complete information on listed seller and product being offered is important for purchase decision.'].sort_values(),palette=None)
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: Complete information on listed seller and product being offered is important for purchase decision., dtype: int64
# <AxesSubplot:xlabel='Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# Most of our respondants find that it is necessary that the complete information on listed seller and product being offered is needed for making their purchase decision. Very few respondants strongly disagree.

# %%
plt.figure(figsize=(5,5))
print(df_cr['All relevant information on listed products must be stated clearly.'].value_counts())
df_cr['All relevant information on listed products must be stated clearly.'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: All relevant information on listed products must be stated clearly., dtype: int64
# <AxesSubplot:ylabel='All relevant information on listed products must be stated clearly.'>

# %% [markdown]
# More than 80 % of our respondants feel that All relevant information on listed products must be stated clearly. It is of utmost importance to them. A very small percentage of our respondants disagree with the statement.

# %%
plt.figure(figsize=(7,6))
print(df_cr['Ease of navigation in website.'].value_counts())
sns.countplot(df_cr['Ease of navigation in website.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease of navigation in website., dtype: int64
# <AxesSubplot:xlabel='Ease of navigation in website.', ylabel='count'>

# %% [markdown]
# Most of our respondants found that the website was easy to navigate, they did not find any problems while navigating the website. 23 of our respondants faced problems during navigation of the website.

# %%
plt.figure(figsize=(8,8))
print(df_cr['Loading and processing speed.'].value_counts())
sns.countplot(y=df_cr['Loading and processing speed.'].sort_values(),palette="Set1")
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: Loading and processing speed., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Loading and processing speed.'>

# %% [markdown]
# Most of our respondants strongly agreed that bthe loading and the processing speed of the website was great(227). 30 respondants disagreed with the statement and found the loading and processing speed not up to mark.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['User friendly Interface of the website.'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['User friendly Interface of the website.'].sort_values(),palette="Set3")
df_cr['User friendly Interface of the website.'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: User friendly Interface of the website., dtype: int64

# %% [markdown]
# About 70 % of respomndants found the website to have a user-friendly interface. Few of our respondants were indifferent towards the statement. And, lastly some respondants disagreed with the statement.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['Convenient Payment methods.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['Convenient Payment methods.'])
df_cr['Convenient Payment methods.'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: Convenient Payment methods., dtype: int64

# %% [markdown]
# A large number of our respondants found the payment methods to be convenient. And, a small portion found the payment methods to not be convenient

# %%
plt.figure(figsize=(8,8))
print(df_cr['Trust that the online retail store will fulfill its part of the transaction at the stipulated time.'].value_counts())
sns.countplot(df_cr['Trust that the online retail store will fulfill its part of the transaction at the stipulated time.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: Trust that the online retail store will fulfill its part of the transaction at the stipulated time., dtype: int64
# <AxesSubplot:xlabel='Trust that the online retail store will fulfill its part of the transaction at the stipulated time.', ylabel='count'>

# %% [markdown]
# Most of the respondants felt that the online retail store will fulfill its part of the transaction at the stipulated time. On the other hand, some of our respondants didn't find the online reatil store trustworthy.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['Empathy (readiness to assist with queries) towards the customers.'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['Empathy (readiness to assist with queries) towards the customers.'])
df_cr['Empathy (readiness to assist with queries) towards the customers.'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: Empathy (readiness to assist with queries) towards the customers., dtype: int64

# %% [markdown]
# Majority of our respondants found that the website was empathetic towards the customers. A small minority were indifferent and disagreed with the statement.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['Being able to guarantee the privacy of the customer.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['Being able to guarantee the privacy of the customer.'].sort_values(),palette="Set2")
df_cr['Being able to guarantee the privacy of the customer.'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: Being able to guarantee the privacy of the customer., dtype: int64

# %% [markdown]
# A large part of our repondants agreed that the website was able to guarantee privacy of the customer.Very few were indifferent.

# %%
plt.figure(figsize=(5,5))
print(df_cr['Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts())
df_cr['Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64
# <AxesSubplot:ylabel='Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'>

# %% [markdown]
# More than 80 % of the respondants found the responsiveness & availability of several communication channels (email, online rep, twitter, phone etc.) on the website to be good.

# %%
plt.figure(figsize=(9,6))
print(df_cr['Online shopping gives monetary benefit and discounts.'].value_counts())
sns.countplot(df_cr['Online shopping gives monetary benefit and discounts.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: Online shopping gives monetary benefit and discounts., dtype: int64
# <AxesSubplot:xlabel='Online shopping gives monetary benefit and discounts.', ylabel='count'>

# %% [markdown]
# Majority of the respondants strongly agree and agree that Online shopping gives monetary benefit and discounts. Few respondants disagreed with the statement.

# %%
plt.figure(figsize=(9,6))
print(df_cr['Enjoyment is derived from shopping online.'].value_counts())
sns.countplot(df_cr['Enjoyment is derived from shopping online.'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: Enjoyment is derived from shopping online., dtype: int64
# <AxesSubplot:xlabel='Enjoyment is derived from shopping online.', ylabel='count'>

# %% [markdown]
# While most of the respondants found online shopping to be enjoyable. Many were indifferent towards the statement. While even few disagreed with the statement.

# %%
plt.figure(figsize=(5,5))
print(df_cr['Shopping online is convenient and flexible.'].value_counts())
df_cr['Shopping online is convenient and flexible.'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: Shopping online is convenient and flexible., dtype: int64
# <AxesSubplot:ylabel='Shopping online is convenient and flexible.'>

# %% [markdown]
# A large number of our respondants agreed with : Shopping online is convenient and flexible. While a considerate amount found the statement indifferent. Veryfew disagreed with the statement.

# %%
plt.figure(figsize=(6,7))
print(df_cr['Return and replacement policy of the e-tailer is important for purchase decision.'].value_counts())
df_cr['Return and replacement policy of the e-tailer is important for purchase decision.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: Return and replacement policy of the e-tailer is important for purchase decision., dtype: int64
# <AxesSubplot:ylabel='Return and replacement policy of the e-tailer is important for purchase decision.'>

# %% [markdown]
# More than 70 % of our respondants found the return and repalcement policy to be important in the purchase decision. 19 % agreed with the statement and 7.4 % disagreed with the statement

# %%
plt.figure(figsize=(6,6))
print(df_cr[ 'Gaining access to loyalty programs is a benefit of shopping online.'].value_counts())
sns.countplot(df_cr['Gaining access to loyalty programs is a benefit of shopping online.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: Gaining access to loyalty programs is a benefit of shopping online., dtype: int64
# <AxesSubplot:xlabel='Gaining access to loyalty programs is a benefit of shopping online.', ylabel='count'>

# %% [markdown]
# Most of our respondants agreed that Gaining access to loyalty programs is a benefit of shopping online. Few disagreed with this statement.

# %%
plt.figure(figsize=(5,5))
print(df_cr['Displaying quality Information on the website improves satisfaction of customers.'].value_counts())
df_cr['Displaying quality Information on the website improves satisfaction of customers.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: Displaying quality Information on the website improves satisfaction of customers., dtype: int64
# <AxesSubplot:ylabel='Displaying quality Information on the website improves satisfaction of customers.'>

# %% [markdown]
# Almost 80 % of the respondants agree that Displaying quality Information on the website improves satisfaction of customers. About 20.8 % were indifferent.

# %%
plt.figure(figsize=(5,5))
print(df_cr['User derive satisfaction while shopping on a good quality website or application.'].value_counts())
df_cr['User derive satisfaction while shopping on a good quality website or application.'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: User derive satisfaction while shopping on a good quality website or application., dtype: int64
# <AxesSubplot:ylabel='User derive satisfaction while shopping on a good quality website or application.'>

# %% [markdown]
# More than 90 % of respondants agree that Users derive satisfaction while shopping on a good quality website or application.

# %%
plt.figure(figsize=(6,6))
print(df_cr['Net Benefit derived from shopping online can lead to users satisfaction.'].value_counts())
df_cr['Net Benefit derived from shopping online can lead to users satisfaction.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: Net Benefit derived from shopping online can lead to users satisfaction., dtype: int64
# <AxesSubplot:ylabel='Net Benefit derived from shopping online can lead to users satisfaction.'>

# %% [markdown]
# About 80% of the respondants agree that Net Benefit derived from shopping online can lead to users satisfaction. Whereas 20% Disagree and are indifferent.

# %%
plt.figure(figsize=(6,6))
print(df_cr['User satisfaction cannot exist without trust.'].value_counts())
sns.countplot(y=df_cr['User satisfaction cannot exist without trust.'].sort_values(),palette="Set3")
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: User satisfaction cannot exist without trust., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='User satisfaction cannot exist without trust.'>

# %% [markdown]
# Many respondants strongly agree and agree that there can't be user satisfaction without trust.

# %%
plt.figure(figsize=(5,5))
print(df_cr['Offering a wide variety of listed product in several category.'].value_counts())
sns.countplot(y=df_cr['Offering a wide variety of listed product in several category.'].sort_values(),palette=None)
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: Offering a wide variety of listed product in several category., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Offering a wide variety of listed product in several category.'>

# %% [markdown]
# Offering a wide variety of listed product in several categories is important fora majority of our respondants.

# %%
plt.figure(figsize=(6,6))
print(df_cr['Provision of complete and relevant product information.'].value_counts())
sns.countplot(df_cr['Provision of complete and relevant product information.'].sort_values(),palette="Set2")
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: Provision of complete and relevant product information., dtype: int64
# <AxesSubplot:xlabel='Provision of complete and relevant product information.', ylabel='count'>

# %% [markdown]
# Most of our respondants agree and strongly agree that Provision of complete and relevant product information is necessary for customers. Only 5 of our respondants disagree with the statement.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['Monetary savings.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['Monetary savings.'])
df_cr['Monetary savings.'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: Monetary savings., dtype: int64

# %% [markdown]
# Most of our respondants agreed to the statement of monetary savings derived from shopping online.Some disagreed and even fewer were indifferent.

# %%
plt.figure(figsize=(6,6))
print(df_cr['The Convenience of patronizing the online retailer.'].value_counts())
df_cr['The Convenience of patronizing the online retailer.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: The Convenience of patronizing the online retailer., dtype: int64
# <AxesSubplot:ylabel='The Convenience of patronizing the online retailer.'>

# %% [markdown]
# Many respondants agree and strongly agree to The Convenience of patronizing the online retailer.

# %%
plt.figure(figsize=(8,6))
print(df_cr['Shopping on the website gives you the sense of adventure.'].value_counts())
sns.countplot(df_cr['Shopping on the website gives you the sense of adventure.'].sort_values(),palette="Set3")
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: Shopping on the website gives you the sense of adventure., dtype: int64
# <AxesSubplot:xlabel='Shopping on the website gives you the sense of adventure.', ylabel='count'>

# %% [markdown]
# Many respondants agreed and strongly agreed that "Shopping on the website gives you the sense of adventure.". Few disagreed with the statement.

# %%
plt.figure(figsize=(6,6))
print(df_cr['Shopping on your preferred e-tailer enhances your social status.'].value_counts())
df_cr['Shopping on your preferred e-tailer enhances your social status.'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: Shopping on your preferred e-tailer enhances your social status., dtype: int64
# <AxesSubplot:ylabel='Shopping on your preferred e-tailer enhances your social status.'>

# %% [markdown]
# While many agreed with the statement :Shopping on your preferred e-tailer enhances your social status. There was a large number of respondants who were indifferent towards the statement.And, a fairly large number who disagreed with the statement

# %%
plt.figure(figsize=(6,6))
print(df_cr['You feel gratification shopping on your favorite e-tailer.'].value_counts())
df_cr['You feel gratification shopping on your favorite e-tailer.'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: You feel gratification shopping on your favorite e-tailer., dtype: int64
# <AxesSubplot:ylabel='You feel gratification shopping on your favorite e-tailer.'>

# %% [markdown]
# 47.6 % of the respondants strongly agree & agree to feeling gratification when shoping on their favourite retailer.Whereas, 14.9 % of respondants disagree or strongly disagree to the statement.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df_cr['Shopping on the website helps you fulfill certain roles.'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df_cr['Shopping on the website helps you fulfill certain roles.'])
df_cr['Shopping on the website helps you fulfill certain roles.'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: Shopping on the website helps you fulfill certain roles., dtype: int64

# %% [markdown]
# Most respondants agree with the statement: Shopping on the website helps you fulfill certain roles. Some disagree strongly. Many are indifferent.

# %%
plt.figure(figsize=(6,6))
print(df_cr['Getting value for money spent.'].value_counts())
df_cr['Getting value for money spent.'].value_counts().plot.pie(colors=colors,autopct='%1.1f%%')
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: Getting value for money spent., dtype: int64
# <AxesSubplot:ylabel='Getting value for money spent.'>

# %% [markdown]
# More than 80 % of the respondants agree to the statement: Getting value for money spent.

# %%
plt.figure(figsize=(10,8))
print(df_cr['From the following, tick any (or all) of the online retailers you have shopped from:'].value_counts())
sns.countplot(y=df_cr['From the following, tick any (or all) of the online retailers you have shopped from:'].sort_values(),palette="Set2")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from:, dtype: int64
# <AxesSubplot:xlabel='count', ylabel='From the following, tick any (or all) of the online retailers you have shopped from:'>

# %% [markdown]
# Most of the Customers have shopped from all ("Amazon.in","Flipkart.com","Paytm.com","Myntra.com","Snapdeal.com").

# %%
plt.figure(figsize=(10,8))
print(df_cr['Easy to use website or application.'].value_counts())
sns.countplot(y=df_cr['Easy to use website or application.'].sort_values(),palette="Set3")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Easy to use website or application.'>

# %% [markdown]
# Most respondants find all the websites("Amazon","Flipkart","Paytm","Myntra","Snapdeal") to be easy to use.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Visual appealing web-page layout.'].value_counts())
sns.countplot(y=df_cr['Visual appealing web-page layout.'].sort_values(),palette="Set1")
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Visual appealing web-page layout.'>

# %% [markdown]
# Amazon.in, Flipkart.com have the most Visual appealing web-page layout.Followed by Snapdeal.com.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Wild variety of product on offer.'].value_counts())
sns.countplot(y=df_cr['Wild variety of product on offer.'].sort_values(),palette="Set2")
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Wild variety of product on offer.'>

# %% [markdown]
# Amazon.in, Flipkart.com have a wide variety of products to offer, followed by snapdeal.com and myntra.com. Lastly, Paytm.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Complete, relevant description information of products.'].value_counts())
sns.countplot(y=df_cr['Complete, relevant description information of products.'].sort_values(),palette="Set3")
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Complete, relevant description information of products.'>

# %% [markdown]
# It is observed that Amazon.in, Flipkart.com show Complete, relevant description information of products

# %%
plt.figure(figsize=(10,8))
print(df_cr['Fast loading website speed of website and application.'].value_counts())
sns.countplot(y=df_cr['Fast loading website speed of website and application.'].sort_values(),palette="Set1")
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Fast loading website speed of website and application.'>

# %% [markdown]
# It is observed that Amazon.in has the Fast loading website speed of all other websites and applications."Paytm" followed by "Flipkart.com". Slowest website is the "Snapdeal.com".

# %%
plt.figure(figsize=(10,8))
print(df_cr['Reliability of the website or application.'].value_counts())
sns.countplot(y=df_cr['Reliability of the website or application.'].sort_values(),palette="Set2")
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Reliability of the website or application.'>

# %% [markdown]
# It is observed thatAmazon.in is the most reliable. Followed by Flipkart.com, Paytm.com, and Myntra.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Quickness to complete purchase.'].value_counts())
sns.countplot(y=df_cr['Quickness to complete purchase.'].sort_values(),palette="Set3")
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Quickness to complete purchase.'>

# %% [markdown]
# Amazon.in, Flipkart.com, Paytm.com show Quickness to complete purchase.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Availability of several payment options.'].value_counts())
sns.countplot(y=df_cr['Availability of several payment options.'].sort_values(),palette="Set1")
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Availability of several payment options.'>

# %% [markdown]
# Again, Amazon.in, Flipkart.com have the most Availability of several payment options.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Speedy order delivery.'].value_counts())
sns.countplot(y=df_cr['Speedy order delivery.'].sort_values(),palette="Set2")
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Speedy order delivery.'>

# %% [markdown]
# We can see that "Amazon.com" delivers the product fastly followed by the "Flipkart.com"

# %%
plt.figure(figsize=(10,8))
print(df_cr['Privacy of customers’ information.'].value_counts())
sns.countplot(y=df_cr['Privacy of customers’ information.'].sort_values(),palette="Set3")
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Flipkart.com                                                    15
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Privacy of customers’ information.'>

# %% [markdown]
# It is observed that Amazon.in got the highest in Privacy of customers’ information. Followed by Flipkart.com and Paytm.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Security of customer financial information.'].value_counts())
sns.countplot(y=df_cr['Security of customer financial information.'].sort_values(),palette="Set1")
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Security of customer financial information.'>

# %% [markdown]
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com all ranked high in Security of customers' financial information.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Perceived Trustworthiness.'].value_counts())
sns.countplot(y=df_cr['Perceived Trustworthiness.'].sort_values(),palette="Set2")
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Perceived Trustworthiness.'>

# %% [markdown]
# It is observed that Amazon.in, Flipkart.com had ranked high in percieved trustworthiness, followed by snapdeal.com and myntra.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Presence of online assistance through multi-channel.'].value_counts())
sns.countplot(y=df_cr['Presence of online assistance through multi-channel.'].sort_values(),palette="Set3")
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Presence of online assistance through multi-channel.'>

# %% [markdown]
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com had Presence of online assistance through multi-channel.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Longer time to get logged in (promotion, sales period).'].value_counts())
sns.countplot(y=df_cr['Longer time to get logged in (promotion, sales period).'].sort_values(),palette="Set1")
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period)., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Longer time to get logged in (promotion, sales period).'>

# %% [markdown]
# It is observed that Amazon.in, Paytm.com, Myntra.com took Longer time to get logged in (promotion, sales period).

# %%
plt.figure(figsize=(10,8))
print(df_cr['Longer time in displaying graphics and photos (promotion, sales period).'].value_counts())
sns.countplot(y=df_cr['Longer time in displaying graphics and photos (promotion, sales period).'].sort_values(),palette="Set2")
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period)., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Longer time in displaying graphics and photos (promotion, sales period).'>

# %% [markdown]
# Amazon.in and Flipkart.com showed the highest in Longer time in displaying graphics and photos (promotion, sales period).

# %%
plt.figure(figsize=(10,8))
print(df_cr['Late declaration of price (promotion, sales period).'].value_counts())
sns.countplot(y=df_cr['Late declaration of price (promotion, sales period).'].sort_values(),palette="Set3")
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period)., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Late declaration of price (promotion, sales period).'>

# %% [markdown]
# Late declaration of price (promotion, sales period). was observed in Myntra.com followed by Paytm.com & Snapdeal.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Longer page loading time (promotion, sales period).'].value_counts())
sns.countplot(y=df_cr['Longer page loading time (promotion, sales period).'].sort_values(),palette="Set1")
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period)., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Longer page loading time (promotion, sales period).'>

# %% [markdown]
# Longer page loading time (promotion, sales period). was observed in Myntra.com & Paytm.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Limited mode of payment on most products (promotion, sales period).'].value_counts())
sns.countplot(y=df_cr['Limited mode of payment on most products (promotion, sales period).'].sort_values(),palette="Set2")
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period)., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Limited mode of payment on most products (promotion, sales period).'>

# %% [markdown]
# As per our respondants, Snapdeal.com had Limited mode of payment on most products (promotion, sales period). Followed by Amazon.in and Flipkart.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Longer delivery period.'].value_counts())
sns.countplot(y=df_cr['Longer delivery period.'].sort_values(),palette="Set3")
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Longer delivery period.'>

# %% [markdown]
# According to the chart above, Longer delivery period was observed inSnapdeal.com & Paytm.com.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Change in website/Application design.'].value_counts())
sns.countplot(y=df_cr['Change in website/Application design.'].sort_values(),palette="Set1")
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Change in website/Application design.'>

# %% [markdown]
# According to the respondants, changes to app design took place in Amazon.in and Paytm.com

# %%
plt.figure(figsize=(10,8))
print(df_cr['Frequent disruption when moving from one page to another.'].value_counts())
sns.countplot(y=df_cr['Frequent disruption when moving from one page to another.'].sort_values(),palette="Set2")
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Frequent disruption when moving from one page to another.'>

# %% [markdown]
# Frequent disruption when moving from one page to another was found in Amazon.in, Myntra.com, Snapdeal.com.

# %%
plt.figure(figsize=(10,8))
print(df_cr['Website is as efficient as before.'].value_counts())
sns.countplot(y=df_cr['Website is as efficient as before.'].sort_values(),palette="Set3")
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before., dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Website is as efficient as before.'>

# %% [markdown]
# It is observed that Amazon.in has remained as efficient as before according to our respondants. Snapdeal.com has no remained as efficient as before

# %%
plt.figure(figsize=(10,8))
print(df_cr['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
sns.countplot(y=df_cr['Which of the Indian online retailer would you recommend to a friend?'].sort_values(),palette="Set1")
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Which of the Indian online retailer would you recommend to a friend?'>

# %% [markdown]
# We can see that mostly people are recommending "Amazon.com" & "Flipkart.com" to others. Least recommended website is "Paytm" & "Snapdeal"

# %% [markdown]
# # Bivariate Analysis

# %%
#Getting column names
df_cr.columns
# Out:
# Index(['Gender of respondent', 'How old are you? ',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online?',
#        'How many times you have made an online purchase in the past 1 year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %%
sns.factorplot('Gender of respondent',kind='count',data=df_cr,hue='How old are you? ',palette="hls")

# %% [markdown]
# We can see that Females are doing more shopping compared to Males. And females with age group 21-30 and men of age group 31-40 are shopping more than other age groups.

# %%
sns.factorplot('Which city do you shop online from?',kind='count',data=df_cr,hue='Since How Long You are Shopping Online?',palette="hls")
plt.xticks(rotation=90);

# %% [markdown]
# As we can see here more customers are in Greater Noida and they have above 4 years of online shopping experience.

# %%
sns.factorplot('How many times you have made an online purchase in the past 1 year?',kind='count',data=df_cr,hue='How do you access the internet while shopping on-line?',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# In all the frequencies of online purchase in past 1 year, the usage of mobile internet for internet access is high.

# %%
sns.factorplot('Which device do you use to access the online shopping?',kind='count',data=df_cr,hue='What is the screen size of your mobile device?',palette="Set3")

# %% [markdown]
# Most the respondants were smartphone users with maximum screen size of 5.5 inches. Other devices screen size is not specified.

# %%
sns.factorplot('What is the operating system (OS) of your device?',kind='count',data=df_cr,hue='What browser do you run on your device to access the website?',palette="Set1")

# %% [markdown]
# All the windows users and most of the Android users use Google Chrome as their browser.IOS/Mac users use Safari as their browser.

# %%
sns.factorplot('Which channel did you follow to arrive at your favorite online store for the first time?',kind='count',data=df_cr,hue='After first visit, how do you reach the online retail store?',palette="Set2")

# %% [markdown]
# Most of the respondants used Search Engine to visit the online store for first time and after first visit, they reached the online store using search engines again. So search engines are  good to get more number of customers.

# %%
sns.factorplot('How much time do you explore the e- retail store before making a purchase decision?',kind='count',data=df_cr,hue='What is your preferred payment Option?',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most of the respondants explored the e-retail store for more than 15 mins before making a purchase decision and maximum number of respondants used credit/debit cards as their payment option.

# %%
sns.factorplot('How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',kind='count',data=df_cr,hue='Why did you abandon the “Bag”, “Shopping Cart”?					',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Maximum no of respondants abandon their shopping cart: 'sometimes' and the main reason for abandoning is 'better alternative offer'.

# %%
sns.factorplot('The content on the website must be easy to read and understand.',kind='count',data=df_cr,hue='Information on similar product to the one highlighted  is important for product comparison.',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Most of our respondants strongly agree that the content on the website must be easy to read and understand and also the information on similar products must be highlighted.

# %%
sns.factorplot('Complete information on listed seller and product being offered is important for purchase decision.',kind='count',data=df_cr,hue='All relevant information on listed products must be stated clearly.',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most of the respondants agree that complete information on the seller and all relevant information on products listed is important for purchase decision.

# %%
sns.factorplot('Ease of navigation in website.',kind='count',data=df_cr,hue='Loading and processing speed.',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Most of the respondants Agree to the easy navigation in the website & the loading and processing speed.

# %%
sns.factorplot('User friendly Interface of the website.',kind='count',data=df_cr,hue='Convenient Payment methods.',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants strongly agreed that the website had a User Friendly Interface and had Convenient Payment Methods.

# %%
sns.factorplot('Trust that the online retail store will fulfill its part of the transaction at the stipulated time.',kind='count',data=df_cr,hue='Empathy (readiness to assist with queries) towards the customers.',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most Respondants agree that they trusted the online retail store would fulfill its part of the transaction in the stipulated time. Also they agree that the online retail store had empathy towards the customers.

# %%
sns.factorplot('Being able to guarantee the privacy of the customer.',kind='count',data=df_cr,hue='Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Most of the respondants want to have the guarantee of privacy for the customer and they also wish to have responsiveness, availability of several communication channels.

# %%
sns.factorplot('Online shopping gives monetary benefit and discounts.',kind='count',data=df_cr,hue='Enjoyment is derived from shopping online.',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Maximum number of respondants agree that Enjoyment is derived from online shopping, also online shopping gives monetary benefits and discounts.

# %%
sns.factorplot('Shopping online is convenient and flexible.',kind='count',data=df_cr,hue='Return and replacement policy of the e-tailer is important for purchase decision.',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agree that shopping online is convenient and flexible and they also agree that return and replacement policy of the e-tailer is important for purchase decision.

# %%
sns.factorplot('Gaining access to loyalty programs is a benefit of shopping online.',kind='count',data=df_cr,hue='Displaying quality Information on the website improves satisfaction of customers.',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agree with 'Gaining access to loyalty programs is a benefit of shopping online' and they also agree that displaying quality information on the website improves satisfaction of customers.

# %%
sns.factorplot('User derive satisfaction while shopping on a good quality website or application.',kind='count',data=df_cr,hue='Net Benefit derived from shopping online can lead to users satisfaction.',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agree that users derive satisfaction while shopping on a good quality website or application. Also, net benefit derived from shopping online can lead to users satisfaction.

# %%
sns.factorplot('User satisfaction cannot exist without trust.',kind='count',data=df_cr,hue='Offering a wide variety of listed product in several category.',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most of the respondants agree and strongly agree tha user satisfsaction cannot exist without trust and also that there must be a wide variety of listed product in several categories.

# %%
sns.factorplot('Provision of complete and relevant product information.',kind='count',data=df_cr,hue='Monetary savings.',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agree and strongly agree to "provision of complete and relevant product information" and they also agree to have monetary savings.

# %%
sns.factorplot('The Convenience of patronizing the online retailer.',kind='count',data=df_cr,hue='Shopping on the website gives you the sense of adventure.',palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agree to having the convenience of patronizing the online retailer and they also agree that shooping on website gives us the sense of adventure.

# %%
sns.factorplot('Shopping on your preferred e-tailer enhances your social status.',kind='count',data=df_cr,hue='You feel gratification shopping on your favorite e-tailer.',palette="Set3")
plt.xticks(rotation=90);

# %% [markdown]
# Most respondants agrees that we feel gratification shopping on there favorite e-tailer and also that shopping on your preferred e-tailer enhances their social status.

# %%
sns.factorplot('Shopping on the website helps you fulfill certain roles.',kind='count',data=df_cr,hue='Getting value for money spent.',palette="Set1")
plt.xticks(rotation=90);

# %% [markdown]
# Most of our respondants agree that shopping on the websites helps to fulfill certain roles and also that they are getting value for money spent.

# %% [markdown]
# # Overall Analysis

# %% [markdown]
# Most of the respondants are females with age from 20-50. They used mobile internet to access the online shopping platform.
# Most of the respondants use smartphones with 5.5 inch screens.

# %% [markdown]
# Windows as operating sysytem.
# And most of the respondants used search engines to get into the online retail store the first time and frequently after that.
# Maximum number of respondants use their debit/credit cards for payment.

# %% [markdown]
# Compared to other shopping platforms, Amazon.in and Flipkart.com have maximum benefits and very few drawbacks.

# %% [markdown]
# Almost all respondants agree or strongly agree to have easy content readability, similar product infomation, sellers infomation, Clarity in product information, Easy navigation, a good loading and processing speed, a User-Friendly Interface, many conveninet payment methods, Trust in Timely Fulfilment of orders, Customer Empathy, Guarantee of Customer's Privacy, Various Response Channels, Benefits & Discount, Enjoyment from Online Shopping, Convenience Flexibility, Good Returns & Replacement Policy, Access to Loyalty Programs, Satisfaction in Quality Information, Website Quality Satisfaction, Net Benefit Satisfaction, User Trust, Products in Several Categories, Relevant Product Information, Monetary Savings, Patronizing Convenience, Deriving a sense of Adventure from shopping online , Enhances Social Status, Gratification Shopping, Role Fulfilment, Money's Worth.

# %% [markdown]
# # Conclusion

# %% [markdown]
# There is high customer retention and satisfaction in:

# %% [markdown]
# Amazon.in
# Flipkart.com

# %% [markdown]
# There is a high risk of customer churn in:

# %% [markdown]
# Myntra.com
# Snapdeal.com
# Paytm.com

# %% [markdown]
# When customers are satisfied with a company or service, there is a high possibility that they will share their experience with other people (other customers) and recommend the services of said company. Therefore, it is very important for E-commerce retailers to take into account the customer satisfaction because this will help retain customer loyalty as well as attract new potential customers. All this leads to an increase in sales, which is the main goal of any company/business.
