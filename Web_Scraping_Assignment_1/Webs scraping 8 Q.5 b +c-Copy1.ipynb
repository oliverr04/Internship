# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    
    pagem=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
    
except Exception as e:
    error_type,error_obj,error_info=sys.exc_info()
    print('ERROR FOR LINK: ',url)
    print(error_type,'Line: ',error_info.tb_lineno)
    
time.sleep(2)

# %%
pagem
# Out:
# <Response [200]>

# %%
soupm=BeautifulSoup(pagem.content,'html.parser')
soupm
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
menb=soupm.find('table',class_="table rankings-table")
for team in menb.find_all('td'):
    print(team.text)
# Out:
#                             1
#
#
#
# (0)
#
#
#
#
#
#
#
#
#
#
#
# Babar Azam
#
#
#
#
#
#
# PAK
#
#
#
# 873
#
#
#
#
#                                 873 v England, 13/07/2021
#
#
#
#
#
#
#
#
#                                     2
#
#
#
# (0)
#
#
#
#
# Virat Kohli
#
#
#
# IND
#
# 811
#
#                                 911 v England, 12/07/2018
#
#
#
#
#                                     3
#
#
#
# (0)
#
#
#
#
# Quinton de Kock
#
#
#
# SA
#
# 796
#
#                                 813 v Sri Lanka, 10/03/2019
#
#
#
#
#                                     4
#
#
#
# (0)
#
#
#
#
# Rohit Sharma
#
#
#
# IND
#
# 791
#
#                                 885 v Sri Lanka, 06/07/2019
#
#
#
#
#                                     5
#
#
#
# (0)
#
#
#
#
# Aaron Finch
#
#
#
# AUS
#
# 779
#
#                                 798 v England, 25/06/2019
#
#
#
#
#                                     6
#
#
#
# (0)
#
#
#
#
# Rassie van der Dussen
#
#
#
# SA
#
# 776
#
# ...

# %%
menb
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">
# <div class="rankings-block__pos-container">
# <span class="rankings-block__pos-number">
#                             1
#                         </span>
# <div class="ranking-pos no-change">
# <span class="ranking-pos__no-change-line"></span>
# <span class="ranking-pos__change-amount">(0)</span>
# </div>
# </div>
# </td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# ...

# %%
batsmen=[]
team=[]
rating=[]

# %%
for player in menb.find_all('td',class_="table-body__cell rankings-table__name name")[:9]:
    print(player.text)
# Out:
# Virat Kohli
#
#
# Quinton de Kock
#
#
# Rohit Sharma
#
#
# Aaron Finch
#
#
# Rassie van der Dussen
#
#
# Jonny Bairstow
#
#
# David Warner
#
#
# Fakhar Zaman
#
#
# Joe Root

# %%
batsmen2=[]
for player in menb.find_all('div',class_="rankings-block__banner--name-large")[:9]:
    batsmen2.append(player.text)

# %%
batsmen2
# Out:
# ['Babar Azam']

# %%
for i in menb.find_all('td',class_="table-body__cell rankings-table__name name")[:9]:
    batsmen.append(i.text.replace('\n',''))
batsmen
# Out:
# ['\nVirat Kohli\n',
#  '\nQuinton de Kock\n',
#  '\nRohit Sharma\n',
#  '\nAaron Finch\n',
#  '\nRassie van der Dussen\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nFakhar Zaman\n',
#  '\nJoe Root\n',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Aaron Finch',
#  'Rassie van der Dussen',
#  'Jonny Bairstow',
#  'David Warner',
#  'Fakhar Zaman',
#  'Joe Root']

# %%
batsmen1=[]
for i in menb.find_all('td',class_="table-body__cell rankings-table__name name")[:9]:
    batsmen1.append(i.text.replace('\n',''))
batsmen1
# Out:
# ['Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Aaron Finch',
#  'Rassie van der Dussen',
#  'Jonny Bairstow',
#  'David Warner',
#  'Fakhar Zaman',
#  'Joe Root']

# %%
batsmen2.extend(batsmen1)

# %%
batsmen2
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Aaron Finch',
#  'Rassie van der Dussen',
#  'Jonny Bairstow',
#  'David Warner',
#  'Fakhar Zaman',
#  'Joe Root']

# %%
team2=[]
for player in menb.find_all('div',class_="rankings-block__banner--nationality"):
    team2.append(player.text.replace('\n',''))
    
team2
# Out:
# ['PAK']

# %%
for i in menb.find_all('span',class_="table-body__logo-text")[:9]:
    team.append(i.text.replace('\n',''))
team
# Out:
# ['IND', 'SA', 'IND', 'AUS', 'SA', 'ENG', 'AUS', 'PAK', 'ENG']

# %%
team2.extend(team)

# %%
team2
# Out:
# ['PAK', 'IND', 'SA', 'IND', 'AUS', 'SA', 'ENG', 'AUS', 'PAK', 'ENG']

# %%
rating2=[]
for player in menb.find_all('div',class_="rankings-block__banner--rating"):
    rating2.append(player.text.replace('\n',''))
    
rating2
# Out:
# ['873']

# %%
for i in menb.find_all('td',class_="table-body__cell rating")[:9]:
    rating.append(i.text.replace('\n',''))
rating
# Out:
# ['811', '796', '791', '779', '776', '775', '762', '741', '740']

# %%
rating2.extend(rating)

# %%
rating2
# Out:
# ['873', '811', '796', '791', '779', '776', '775', '762', '741', '740']

# %%
import pandas as pd
batting=pd.DataFrame({'Batsmen':batsmen2,'Team':team2,'Rating':rating2})
batting
# Out:
#                  Batsmen Team Rating
# 0             Babar Azam  PAK    873
# 1            Virat Kohli  IND    811
# 2        Quinton de Kock   SA    796
# 3           Rohit Sharma  IND    791
# 4            Aaron Finch  AUS    779
# 5  Rassie van der Dussen   SA    776
# 6         Jonny Bairstow  ENG    775
# 7           David Warner  AUS    762
# 8           Fakhar Zaman  PAK    741
# 9               Joe Root  ENG    740

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    
    pagebow=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
    
except Exception as e:
    error_type,error_obj,error_info=sys.exc_info()
    print('ERROR FOR LINK: ',url)
    print(error_type,'Line: ',error_info.tb_lineno)
    
time.sleep(2)

# %%
pagebow
# Out:
# <Response [200]>

# %%
soupmbow=BeautifulSoup(pagebow.content,'html.parser')
soupmbow
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" property="og:title"/>
# ...

# %%
menbow=soupmbow.find('table',class_="table rankings-table")
for team in menbow.find_all('td'):
    print(team.text)
# Out:
#                             1
#
#
#
# (0)
#
#
#
#
#
#
#
#
#
#
#
# Trent Boult
#
#
#
#
#
#
# NZ
#
#
#
# 737
#
#
#
#
#                                 770 v West Indies, 22/06/2019
#
#
#
#
#
#
#
#
#                                     2
#
#
#
# (0)
#
#
#
#
# Josh Hazlewood
#
#
#
# AUS
#
# 709
#
#                                 733 v England, 26/01/2018
#
#
#
#
#                                     3
#
#
#
# (0)
#
#
#
#
# Chris Woakes
#
#
#
# ENG
#
# 700
#
#                                 711 v Sri Lanka, 04/07/2021
#
#
#
#
#                                     4
#
#
#
# (0)
#
#
#
#
# Matt Henry
#
#
#
# NZ
#
# 691
#
#                                 691 v Bangladesh, 26/03/2021
#
#
#
#
#                                     5
#
#
#
# (0)
#
#
#
#
# Mujeeb Ur Rahman
#
#
#
# AFG
#
# 681
#
#                                 712 v Ireland, 24/01/2021
#
#
#
#
#                                     6
#
#
#
# (0)
#
#
#
#
# Jasprit Bumrah
#
#
#
# IND
#
# 679
#
# ...

# %%
menbow
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">
# <div class="rankings-block__pos-container">
# <span class="rankings-block__pos-number">
#                             1
#                         </span>
# <div class="ranking-pos no-change">
# <span class="ranking-pos__no-change-line"></span>
# <span class="ranking-pos__change-amount">(0)</span>
# </div>
# </div>
# </td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# ...

# %%
bowler=[]
teamb=[]
ratingb=[]

# %%
bowler2=[]
for player in menbow.find_all('div',class_="rankings-block__banner--name-large"):
    bowler2.append(player.text)
bowler2
# Out:
# ['Trent Boult']

# %%
bowler=[]
for i in menbow.find_all('td',class_="table-body__cell rankings-table__name name")[:9]:
    bowler.append(i.text.replace('\n',''))
bowler
# Out:
# ['Josh Hazlewood',
#  'Chris Woakes',
#  'Matt Henry',
#  'Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Mitchell Starc',
#  'Rashid Khan']

# %%
bowler2.extend(bowler)

# %%
bowler2
# Out:
# ['Trent Boult',
#  'Josh Hazlewood',
#  'Chris Woakes',
#  'Matt Henry',
#  'Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Mitchell Starc',
#  'Rashid Khan']

# %%
teamb2=[]
for player in menbow.find_all('div',class_="rankings-block__banner--nationality"):
    teamb2.append(player.text.replace('\n',''))
    
teamb2
# Out:
# ['NZ']

# %%
for i in menbow.find_all('span',class_="table-body__logo-text")[:9]:
    teamb.append(i.text.replace('\n',''))
teamb
# Out:
# ['AUS', 'ENG', 'NZ', 'AFG', 'IND', 'BAN', 'SA', 'AUS', 'AFG']

# %%
teamb2.extend(teamb)

# %%
teamb2
# Out:
# ['NZ', 'AUS', 'ENG', 'NZ', 'AFG', 'IND', 'BAN', 'SA', 'AUS', 'AFG']

# %%
ratingb2=[]
for player in menbow.find_all('div',class_="rankings-block__banner--rating"):
    ratingb2.append(player.text.replace('\n',''))
    
ratingb2
# Out:
# ['737']

# %%
for i in menbow.find_all('td',class_="table-body__cell rating")[:9]:
    ratingb.append(i.text.replace('\n',''))
ratingb
# Out:
# ['709', '700', '691', '681', '679', '664', '658', '652', '650']

# %%
ratingb2.extend(ratingb)

# %%
ratingb2
# Out:
# ['737', '709', '700', '691', '681', '679', '664', '658', '652', '650']

# %%
import pandas as pd
bowling=pd.DataFrame({'Bowler':bowler2,'Team':teamb2,'Rating':ratingb2})
bowling
# Out:
#              Bowler Team Rating
# 0       Trent Boult   NZ    737
# 1    Josh Hazlewood  AUS    709
# 2      Chris Woakes  ENG    700
# 3        Matt Henry   NZ    691
# 4  Mujeeb Ur Rahman  AFG    681
# 5    Jasprit Bumrah  IND    679
# 6      Mehedi Hasan  BAN    664
# 7     Kagiso Rabada   SA    658
# 8    Mitchell Starc  AUS    652
# 9       Rashid Khan  AFG    650
